# %% [markdown]
# kaggle Learn
# Intro to Machine Learning (5.Underfitting and Overfitting)より

# %%
import numpy as np

# %%
def ret_val():
  return np.random.rand()

# %%
keys = list('abcde')
dict_buf = {k:ret_val() for k in keys}

# %%
dict_buf
# Out:
# {'a': 0.8089770849702533,
#  'b': 0.30912156583648187,
#  'c': 0.24343362218945186,
#  'd': 0.31574028876295346,
#  'e': 0.21642616936141545}

# %%
min(dict_buf, key=dict_buf.get)
# Out:
# 'e'
